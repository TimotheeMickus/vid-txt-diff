# %%
import torch
import torch.nn.functional as F
import seaborn as sns

# %%
fake_randn = torch.nn.functional.softmax(torch.randn([200, 3]), dim=-1)
fake_randu = torch.nn.functional.softmax(torch.rand([200, 3]), dim=-1)

# %%
lmap = torch.tensor([ [0, 1, 1/2], [0, 0, (3**.5)/2]])

# %%
X, Y = lmap @ fake_randn.T
sns.set({'figure.figsize':(5,5)})
sns.scatterplot(x=X, y=Y).set(xlim=(0,1), ylim=(0,1))
# Out:
# [(0.0, 1.0), (0.0, 1.0)]
